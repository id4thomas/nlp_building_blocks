# %%
from builder import AgentBuilder

# %%
agent = await AgentBuilder.build(
    name="WeatherAgent",
    user_id="1234",
    tool_names=["location", "weather"],
    user_name="id4thomas"
)

# %%
query="내 현재 위치와 주변 도시들을 알려주고 그 도시들의 날씨들도 알려줘."
# query="서울 주변 도시들을 알려주고 그 도시들의 날씨들도 알려줘. 도시 명칭은 반환값 그대로 사용해"
# query="도구를 사용해서 서울 날씨 알려줘. 도구의 결과도 json 그대로 알려줘"

messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": query}
        ]
    }
]

# %% [markdown]
# # Invoke

# %%
# ainvoke
result = await agent.ainvoke({"messages": messages})

# %%
for msg_i,msg in enumerate(result['messages']):
    print(f"MSG {msg_i} - {type(msg)}")
    print(f"\t{repr(msg.content)}")
    if msg.type=='ai':
        print(f"\ttools:{msg.tool_calls}")
# Out:
# MSG 0 - <class 'langchain_core.messages.human.HumanMessage'>
# 	[{'type': 'text', 'text': '내 현재 위치와 주변 도시들을 알려주고 그 도시들의 날씨들도 알려줘.'}]
# MSG 1 - <class 'langchain_core.messages.ai.AIMessage'>
# 	'알겠습니다. 먼저 현재 위치를 확인하고, 그 주변 도시들을 확인한 후 날씨 정보를 제공해드리겠습니다.\n'
# 	tools:[{'name': 'get_user_location', 'args': {}, 'id': 'chatcmpl-tool-8d912d6ad0a3d982', 'type': 'tool_call'}]
# MSG 2 - <class 'langchain_core.messages.tool.ToolMessage'>
# 	[{'type': 'text', 'text': '{"name":"Seoul","coordinate":{"lat":37.5665,"lon":126.978}}', 'id': 'lc_62771627-2dae-4501-93e7-b0f83be28010'}]
# MSG 3 - <class 'langchain_core.messages.ai.AIMessage'>
# 	'현재 위치는 서울입니다. 주변 도시들을 확인해보겠습니다.\n\n'
# 	tools:[{'name': 'get_nearby_cities', 'args': {'city_name': 'Seoul'}, 'id': 'chatcmpl-tool-974870f8e87e4f0f', 'type': 'tool_call'}]
# MSG 4 - <class 'langchain_core.messages.tool.ToolMessage'>
# 	[{'type': 'text', 'text': '[{"name":"Seongnam","coordinate":{"lat":37.42,"lon":127.1267}},{"name":"Suwon","coordinate":{"lat":37.2636,"lon":127.0286}},{"name":"Changwon","coordinate":{"lat":35.228,"lon":128.6811}}]', 'id': 'lc_dc9ab54a-33d1-4b1d-b431-d73a64d8c43c'}]
# MSG 5 - <class 'langchain_core.messages.ai.AIMessage'>
# 	'서울 주변 도시로는 성남, 수원, 창원이 있습니다. 각 도시의 날씨를 확인해보겠습니다.\n\n\n'
# 	tools:[{'name': 'get_current_weather', 'args': {'city_name': 'Seoul'}, 'id': 'chatcmpl-tool-8595698fc8b5a2a6', 'type': 'tool_call'}, {'name': 'get_current_weather', 'args': {'city_name': 'Seongnam'}, 'id': 'chatcmpl-tool-add6baef2eb3bc5a', 'type': 'tool_call'}, {'name': 'get_current_weather', 'args': {'city_name': 'Suwon'}, 'id': 'chatcmpl-tool-ba148c331718b812', 'type': 'tool_call'}, {'name': 'get_current_weather', 'args': {'city_name': 'Changwon'}, 'id': 'chatcmpl-tool-89694b2998f31a58', 'type': 'tool_call'}]
# MSG 6 - <class 'langchain_core.messages.tool.ToolMessage'>
# 	[{'type': 'text', 'text': '{"time":"20260219-00:00","status":{"temp_cel":1,"condition":"맑음","humidity_pct":54,"wind_kph":14}}', 'id': 'lc_eaf6bb62-cdc8-46d0-bb6b-98b23a31ec8b'}]
# MSG 7 - <class 'langchain_core.messages.tool.ToolMessage'>
# 	[{'type': 'text', 'text': '{"time":"20260219-00:00","status":{"temp_cel":3,"condition":"구름 많음","humidity_pct":51,"wind_kph":11}}', 'id': 'lc_04cf8dc5-5186-4ea6-8e8a-0296f03fc930'}]
# MSG 8 - <class 'langchain_core.messages.tool.ToolMessage'>
# 	[{'type': 'text', 'text': '{"time":"20260219-00:00","status":{"temp_cel":2,"condition":"맑음","humidity_pct":50,"wind_kph":10}}', 'id': 'lc_5a068545-3c16-463a-a337-619c007d1e79'}]
# MSG 9 - <class 'langchain_core.messages.tool.ToolMessage'>
# 	[{'type': 'text', 'text': '{"time":"20260219-00:00","status":{"temp_cel":6,"condition":"구름 조금","humidity_pct":56,"wind_kph":13}}', 'id': 'lc_13412244-7ae7-4930-a232-11893749fb29'}]
# MSG 10 - <class 'langchain_core.messages.ai.AIMessage'>
# 	'현재 날씨 정보를 확인했습니다:\n\n- **서울**: 1°C, 맑음, 습도 54%, 바람 14km/h  \n- **성남**: 3°C, 구름 많음, 습도 51%, 바람 11km/h  \n- **수원**: 2°C, 맑음, 습도 50%, 바람 10km/h  \n- **창원**: 6°C, 구름 조금, 습도 56%, 바람 13km/h  \n\n추가로 예보가 필요하시면 말씀해주세요!'
# 	tools:[]

# %% [markdown]
# # Streaming

# %%
result_stream = agent.astream(
    {"messages": messages},
    stream_mode="updates"
)

# %%
chunk_i=0
async for chunk in result_stream:
    chunk_i+=1
    print(f"Chunk{chunk_i}")
    for node, data in chunk.items():
        last_msg = data["messages"][-1]

        if node == "model":
            print("model node")
            content_blocks = last_msg.content_blocks or []
            tool_calls = [b for b in content_blocks if b.get("type") == "tool_call"]

            if tool_calls:
                for tc in tool_calls:
                    print("\t",{"type": "tool_call", "tool": tc["name"], "args": tc["args"]})
            else:
                text = "".join(b["text"] for b in content_blocks if b.get("type") == "text")
                if text:
                    print("\t",{"type": "ai_message", "content": text})

        elif node == "tools":
            print("tools node")
            content_blocks = last_msg.content_blocks or []
            result = "".join(b["text"] for b in content_blocks if b.get("type") == "text")
            print("\t",{"type": "tool_result", "content": result})
# Out:
# Chunk1
# model node
# 	 {'type': 'tool_call', 'tool': 'get_user_location', 'args': {}}
# Chunk2
# tools node
# 	 {'type': 'tool_result', 'content': '{"name":"Seoul","coordinate":{"lat":37.5665,"lon":126.978}}'}
# Chunk3
# model node
# 	 {'type': 'tool_call', 'tool': 'get_nearby_cities', 'args': {'city_name': 'Seoul'}}
# Chunk4
# tools node
# 	 {'type': 'tool_result', 'content': '[{"name":"Seongnam","coordinate":{"lat":37.42,"lon":127.1267}},{"name":"Suwon","coordinate":{"lat":37.2636,"lon":127.0286}},{"name":"Changwon","coordinate":{"lat":35.228,"lon":128.6811}}]'}
# Chunk5
# model node
# 	 {'type': 'tool_call', 'tool': 'get_current_weather', 'args': {'city_name': 'Seoul'}}
# 	 {'type': 'tool_call', 'tool': 'get_current_weather', 'args': {'city_name': 'Seongnam'}}
# 	 {'type': 'tool_call', 'tool': 'get_current_weather', 'args': {'city_name': 'Suwon'}}
# 	 {'type': 'tool_call', 'tool': 'get_current_weather', 'args': {'city_name': 'Changwon'}}
# Chunk6
# tools node
# 	 {'type': 'tool_result', 'content': '{"time":"20260219-00:00","status":{"temp_cel":3,"condition":"맑음","humidity_pct":54,"wind_kph":14}}'}
# Chunk7
# tools node
# 	 {'type': 'tool_result', 'content': '{"time":"20260219-00:00","status":{"temp_cel":7,"condition":"구름 조금","humidity_pct":60,"wind_kph":11}}'}
# Chunk8
# tools node
# 	 {'type': 'tool_result', 'content': '{"time":"20260219-00:00","status":{"temp_cel":2,"condition":"구름 많음","humidity_pct":54,"wind_kph":11}}'}
# Chunk9
# tools node
# 	 {'type': 'tool_result', 'content': '{"time":"20260219-00:00","status":{"temp_cel":1,"condition":"맑음","humidity_pct":50,"wind_kph":8}}'}
# Chunk10
# model node
# 	 {'type': 'ai_message', 'content': '각 도시의 현재 날씨 정보를 확인했습니다:\n\n- **서울**: 3°C, 맑음, 습도 54%, 풍속 14km/h  \n- **성남**: 2°C, 구름 많음, 습도 54%, 풍속 11km/h  \n- **수원**: 1°C, 맑음, 습도 50%, 풍속 8km/h  \n- **창원**: 7°C, 구름 조금, 습도 60%, 풍속 11km/h  \n\n추가로 궁금한 점이 있으면 말씀해주세요!'}
